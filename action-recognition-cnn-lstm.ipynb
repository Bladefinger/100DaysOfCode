# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Import packages

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
import numpy as np
from tqdm import tqdm
import os
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras.utils import to_categorical
import itertools
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # Import Label File

# %%
label_data = pd.read_csv("../input/ucf101/UCF101TrainTestSplits-RecognitionTask/ucfTrainTestlist/classInd.txt", sep=' ', header=None)
label_data.columns=['index', 'labels']
label_data = label_data.drop(['index'], axis=1)
label_data.head()
# Out:
#            labels
# 0  ApplyEyeMakeup
# 1   ApplyLipstick
# 2         Archery
# 3    BabyCrawling
# 4     BalanceBeam

# %%
#Total Number of video folders for classification
len(label_data)
# Out:
# 101

# %% [markdown]
# # Setting path For data

# %%
path=[]
for label in label_data.labels.values:
    path.append('../input/ucf101/UCF101/UCF-101/'+label+"/")
path[0]
# Out:
# '../input/ucf101/UCF101/UCF-101/ApplyEyeMakeup/'

# %% [markdown]
# # Data Preperation

# %%
#Function for Feature Extraction
def feature_extraction(video_path):
    width=60
    height=60
    sequence_length=5
    frames_list=[]
    #Read the Video
    video_reader = cv2.VideoCapture(video_path)
    #get the frame count
    frame_count=int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    #Calculate the interval after which frames will be added to the list
    skip_interval = max(int(frame_count/sequence_length), 1)
    #iterate through video frames
    for counter in range(sequence_length):
        #Set the current frame postion of the video
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, counter * skip_interval)
        #Read the current frame 
        ret, frame = video_reader.read()
        if not ret:
            break;
        #Resize the image
        frame=cv2.resize(frame, (height, width))
        frame = frame/255
        #Append to the frame
        frames_list.append(frame)
    video_reader.release()
    #Return the Frames List
    return frames_list

# %%
#Function for loading video files, Process and store in a data set
def load_video(datasets):
    global image
    label_index=0
    labels=[]
    images=[]
    #Iterate through each foler corresponding to category
    for folder in datasets:
        for file in tqdm(os.listdir(folder)):
            #Get the path name for each video
            video_path = os.path.join(folder, file)
            #Extract the frames of the current video
            frames_list = feature_extraction(video_path)
            images.append(frames_list)
            labels.append(label_index)
        label_index+=1
    return np.array(images, dtype='float16'), np.array(labels, dtype='int8')

# %%
#Due to memory allocation problem. I will select last 60 video folders for classification
images, labels = load_video(path[41:])
# Out:
# 100%|██████████| 164/164 [00:05<00:00, 28.53it/s]
# 100%|██████████| 125/125 [00:03<00:00, 36.18it/s]
# 100%|██████████| 158/158 [00:19<00:00,  8.16it/s]
# 100%|██████████| 117/117 [00:04<00:00, 28.93it/s]
# 100%|██████████| 121/121 [00:04<00:00, 27.37it/s]
# 100%|██████████| 123/123 [00:03<00:00, 35.56it/s]
# 100%|██████████| 144/144 [00:06<00:00, 23.28it/s]
# 100%|██████████| 141/141 [00:04<00:00, 30.56it/s]
# 100%|██████████| 123/123 [00:12<00:00,  9.61it/s]
# 100%|██████████| 131/131 [00:10<00:00, 12.69it/s]
# 100%|██████████| 127/127 [00:05<00:00, 24.63it/s]
# 100%|██████████| 125/125 [00:03<00:00, 33.36it/s]
# 100%|██████████| 136/136 [00:04<00:00, 33.95it/s]
# 100%|██████████| 110/110 [00:10<00:00, 10.49it/s]
# 100%|██████████| 132/132 [00:04<00:00, 28.13it/s]
# 100%|██████████| 114/114 [00:08<00:00, 14.03it/s]
# 100%|██████████| 113/113 [00:03<00:00, 34.69it/s]
# 100%|██████████| 164/164 [00:15<00:00, 10.92it/s]
# 100%|██████████| 151/151 [00:16<00:00,  9.12it/s]
# 100%|██████████| 164/164 [00:19<00:00,  8.55it/s]
# 100%|██████████| 155/155 [00:20<00:00,  7.59it/s]
# 100%|██████████| 160/160 [00:05<00:00, 28.09it/s]
# 100%|██████████| 105/105 [00:02<00:00, 37.23it/s]
# 100%|██████████| 157/157 [00:18<00:00,  8.69it/s]
# 100%|██████████| 111/111 [00:04<00:00, 26.58it/s]
# 100%|██████████| 100/100 [00:03<00:00, 31.84it/s]
# 100%|██████████| 149/149 [00:04<00:00, 33.58it/s]
# 100%|██████████| 123/123 [00:06<00:00, 18.75it/s]
# 100%|██████████| 100/100 [00:02<00:00, 37.07it/s]
# 100%|██████████| 160/160 [00:07<00:00, 22.84it/s]
# 100%|██████████| 102/102 [00:02<00:00, 34.82it/s]
# 100%|██████████| 111/111 [00:12<00:00,  9.03it/s]
# 100%|██████████| 144/144 [00:06<00:00, 22.04it/s]
# 100%|██████████| 119/119 [00:03<00:00, 33.66it/s]
# 100%|██████████| 137/137 [00:05<00:00, 25.45it/s]
# 100%|██████████| 133/133 [00:04<00:00, 29.61it/s]
# 100%|██████████| 161/161 [00:14<00:00, 11.41it/s]
# 100%|██████████| 144/144 [00:08<00:00, 17.75it/s]
# 100%|██████████| 120/120 [00:03<00:00, 35.06it/s]
# 100%|██████████| 135/135 [00:04<00:00, 30.23it/s]
# 100%|██████████| 100/100 [00:03<00:00, 30.32it/s]
# 100%|██████████| 110/110 [00:09<00:00, 11.38it/s]
# 100%|██████████| 147/147 [00:05<00:00, 28.77it/s]
# 100%|██████████| 137/137 [00:07<00:00, 19.32it/s]
# 100%|██████████| 112/112 [00:09<00:00, 12.14it/s]
# 100%|██████████| 116/116 [00:12<00:00,  9.63it/s]
# 100%|██████████| 126/126 [00:12<00:00,  9.88it/s]
# 100%|██████████| 131/131 [00:04<00:00, 31.45it/s]
# 100%|██████████| 140/140 [00:13<00:00, 10.34it/s]
# 100%|██████████| 100/100 [00:02<00:00, 35.43it/s]
# 100%|██████████| 166/166 [00:04<00:00, 37.76it/s]
# 100%|██████████| 130/130 [00:04<00:00, 31.07it/s]
# 100%|██████████| 119/119 [00:03<00:00, 33.32it/s]
# 100%|██████████| 136/136 [00:11<00:00, 11.65it/s]
# 100%|██████████| 104/104 [00:08<00:00, 12.58it/s]
# 100%|██████████| 116/116 [00:03<00:00, 37.72it/s]
# 100%|██████████| 123/123 [00:04<00:00, 27.48it/s]
# 100%|██████████| 130/130 [00:07<00:00, 17.88it/s]
# 100%|██████████| 152/152 [00:13<00:00, 11.62it/s]
# 100%|██████████| 128/128 [00:03<00:00, 32.10it/s]

# %%
#Shapes
images.shape, pd.Series(labels).shape
# Out:
# ((7832, 5, 60, 60, 3), (7832,))

# %%
#Train Test Split
x_train, x_test, y_train, y_test=train_test_split(images, labels, test_size=0.06, random_state=10)
x_train.shape, x_test.shape, np.array(y_train).shape, np.array(y_test).shape
# Out:
# ((7362, 5, 60, 60, 3), (470, 5, 60, 60, 3), (7362,), (470,))

# %% [markdown]
# # Model Building

# %%
model = Sequential()

model.add(ConvLSTM2D(filters = 16, kernel_size=(3,3), activation='LeakyReLU', data_format='channels_last', return_sequences=True, recurrent_dropout=0.2, input_shape=(x_train.shape[1],x_train.shape[2], x_train.shape[3], 3)))
model.add(MaxPooling3D(pool_size=(1,2,2), padding='same', data_format='channels_last'))
model.add(TimeDistributed(Dropout(0.2)))

model.add(ConvLSTM2D(filters = 16, kernel_size=(3,3), activation='LeakyReLU', data_format='channels_last', return_sequences=True, recurrent_dropout=0.2))
model.add(MaxPooling3D(pool_size=(1,2,2), padding='same', data_format='channels_last'))
model.add(TimeDistributed(Dropout(0.2)))

model.add(ConvLSTM2D(filters = 16, kernel_size=(3,3), activation='LeakyReLU', data_format='channels_last', return_sequences=True, recurrent_dropout=0.2))
model.add(MaxPooling3D(pool_size=(1,2,2), padding='same', data_format='channels_last'))
model.add(TimeDistributed(Dropout(0.2)))

model.add(ConvLSTM2D(filters = 16, kernel_size=(3,3), activation='LeakyReLU', data_format='channels_last', return_sequences=True, recurrent_dropout=0.2))
model.add(MaxPooling3D(pool_size=(1,2,2), padding='same', data_format='channels_last'))
model.add(TimeDistributed(Dropout(0.2)))

model.add(Flatten())
          
model.add(Dense(60, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d (ConvLSTM2D)    (None, 5, 58, 58, 16)     11008
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 5, 29, 29, 16)     0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 5, 29, 29, 16)     0
# _________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)  (None, 5, 27, 27, 16)     18496
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 5, 14, 14, 16)     0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 5, 14, 14, 16)     0
# _________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)  (None, 5, 12, 12, 16)     18496
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 5, 6, 6, 16)       0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 5, 6, 6, 16)       0
# _________________________________________________________________
# conv_lst_m2d_3 (ConvLSTM2D)  (None, 5, 4, 4, 16)       18496
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 5, 2, 2, 16)       0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 5, 2, 2, 16)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 320)               0
# _________________________________________________________________
# dense (Dense)                (None, 60)                19260
# =================================================================
# Total params: 85,756
# Trainable params: 85,756
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics='accuracy')

# %%
#Model training
es = EarlyStopping(monitor='val_loss', patience=5, mode='min', restore_best_weights=True)
history = model.fit(x_train, to_categorical(y_train), batch_size=31, epochs=50, validation_data=(x_test, to_categorical(y_test)), callbacks=[es])
# Out:
# Epoch 1/50
# 238/238 [==============================] - 64s 202ms/step - loss: 3.9931 - accuracy: 0.0433 - val_loss: 3.7693 - val_accuracy: 0.0915
# Epoch 2/50
# 238/238 [==============================] - 60s 252ms/step - loss: 3.5850 - accuracy: 0.1153 - val_loss: 3.4268 - val_accuracy: 0.1532
# Epoch 3/50
# 238/238 [==============================] - 50s 211ms/step - loss: 3.2687 - accuracy: 0.1687 - val_loss: 3.1330 - val_accuracy: 0.2000
# Epoch 4/50
# 238/238 [==============================] - 49s 206ms/step - loss: 2.9911 - accuracy: 0.2161 - val_loss: 2.8863 - val_accuracy: 0.2553
# Epoch 5/50
# 238/238 [==============================] - 49s 205ms/step - loss: 2.7571 - accuracy: 0.2654 - val_loss: 2.7686 - val_accuracy: 0.2787
# Epoch 6/50
# 238/238 [==============================] - 50s 211ms/step - loss: 2.5461 - accuracy: 0.3176 - val_loss: 2.6666 - val_accuracy: 0.3149
# Epoch 7/50
# 238/238 [==============================] - 49s 204ms/step - loss: 2.3578 - accuracy: 0.3619 - val_loss: 2.4234 - val_accuracy: 0.3787
# Epoch 8/50
# 238/238 [==============================] - 48s 204ms/step - loss: 2.1925 - accuracy: 0.4075 - val_loss: 2.3377 - val_accuracy: 0.3809
# Epoch 9/50
# 238/238 [==============================] - 47s 199ms/step - loss: 2.0354 - accuracy: 0.4476 - val_loss: 2.2064 - val_accuracy: 0.4383
# Epoch 10/50
# 238/238 [==============================] - 47s 197ms/step - loss: 1.9125 - accuracy: 0.4701 - val_loss: 2.0980 - val_accuracy: 0.4511
# Epoch 11/50
# 238/238 [==============================] - 48s 201ms/step - loss: 1.7979 - accuracy: 0.5003 - val_loss: 2.0276 - val_accuracy: 0.4596
# Epoch 12/50
# 238/238 [==============================] - 47s 196ms/step - loss: 1.6718 - accuracy: 0.5291 - val_loss: 1.9425 - val_accuracy: 0.4957
# Epoch 13/50
# 238/238 [==============================] - 47s 197ms/step - loss: 1.6011 - accuracy: 0.5456 - val_loss: 1.8864 - val_accuracy: 0.5149
# Epoch 14/50
# 238/238 [==============================] - 48s 202ms/step - loss: 1.5099 - accuracy: 0.5716 - val_loss: 1.8983 - val_accuracy: 0.4894
# Epoch 15/50
# 238/238 [==============================] - 48s 200ms/step - loss: 1.4283 - accuracy: 0.5929 - val_loss: 1.8101 - val_accuracy: 0.5128
# Epoch 16/50
# 238/238 [==============================] - 47s 199ms/step - loss: 1.3916 - accuracy: 0.6087 - val_loss: 1.7463 - val_accuracy: 0.5277
# Epoch 17/50
# 238/238 [==============================] - 47s 197ms/step - loss: 1.3090 - accuracy: 0.6240 - val_loss: 1.6739 - val_accuracy: 0.5638
# Epoch 18/50
# 238/238 [==============================] - 49s 206ms/step - loss: 1.2445 - accuracy: 0.6405 - val_loss: 1.6058 - val_accuracy: 0.5723
# Epoch 19/50
# 238/238 [==============================] - 47s 198ms/step - loss: 1.2108 - accuracy: 0.6487 - val_loss: 1.5766 - val_accuracy: 0.5894
# Epoch 20/50
# 238/238 [==============================] - 49s 204ms/step - loss: 1.1534 - accuracy: 0.6630 - val_loss: 1.4949 - val_accuracy: 0.6170
# Epoch 21/50
# 238/238 [==============================] - 47s 200ms/step - loss: 1.1178 - accuracy: 0.6754 - val_loss: 1.5172 - val_accuracy: 0.6000
# Epoch 22/50
# 238/238 [==============================] - 47s 199ms/step - loss: 1.0726 - accuracy: 0.6847 - val_loss: 1.5539 - val_accuracy: 0.5851
# Epoch 23/50
# 238/238 [==============================] - 49s 204ms/step - loss: 1.0652 - accuracy: 0.6850 - val_loss: 1.4819 - val_accuracy: 0.5936
# Epoch 24/50
# 238/238 [==============================] - 48s 201ms/step - loss: 1.0165 - accuracy: 0.7010 - val_loss: 1.4550 - val_accuracy: 0.6106
# Epoch 25/50
# 238/238 [==============================] - 48s 202ms/step - loss: 1.0036 - accuracy: 0.7076 - val_loss: 1.4128 - val_accuracy: 0.6170
# Epoch 26/50
# 238/238 [==============================] - 48s 202ms/step - loss: 0.9865 - accuracy: 0.7082 - val_loss: 1.3299 - val_accuracy: 0.6489
# Epoch 27/50
# 238/238 [==============================] - 50s 211ms/step - loss: 0.9457 - accuracy: 0.7220 - val_loss: 1.4114 - val_accuracy: 0.6489
# Epoch 28/50
# 238/238 [==============================] - 47s 198ms/step - loss: 0.9142 - accuracy: 0.7294 - val_loss: 1.4067 - val_accuracy: 0.6532
# Epoch 29/50
# 238/238 [==============================] - 48s 203ms/step - loss: 0.8885 - accuracy: 0.7311 - val_loss: 1.4256 - val_accuracy: 0.6553
# Epoch 30/50
# 238/238 [==============================] - 49s 205ms/step - loss: 0.8812 - accuracy: 0.7385 - val_loss: 1.3290 - val_accuracy: 0.6702
# Epoch 31/50
# 238/238 [==============================] - 49s 206ms/step - loss: 0.8640 - accuracy: 0.7419 - val_loss: 1.4314 - val_accuracy: 0.6638
# Epoch 32/50
# 238/238 [==============================] - 47s 199ms/step - loss: 0.8555 - accuracy: 0.7441 - val_loss: 1.3901 - val_accuracy: 0.6511
# Epoch 33/50
# 238/238 [==============================] - 49s 204ms/step - loss: 0.8033 - accuracy: 0.7574 - val_loss: 1.3563 - val_accuracy: 0.6638
# Epoch 34/50
# 238/238 [==============================] - 48s 200ms/step - loss: 0.8168 - accuracy: 0.7499 - val_loss: 1.3601 - val_accuracy: 0.6723
# Epoch 35/50
# 238/238 [==============================] - 49s 204ms/step - loss: 0.7791 - accuracy: 0.7654 - val_loss: 1.2973 - val_accuracy: 0.6723
# Epoch 36/50
# 238/238 [==============================] - 47s 199ms/step - loss: 0.7701 - accuracy: 0.7658 - val_loss: 1.3082 - val_accuracy: 0.6745
# Epoch 37/50
# 238/238 [==============================] - 47s 198ms/step - loss: 0.7553 - accuracy: 0.7703 - val_loss: 1.2496 - val_accuracy: 0.6766
# Epoch 38/50
# 238/238 [==============================] - 48s 201ms/step - loss: 0.7373 - accuracy: 0.7766 - val_loss: 1.3150 - val_accuracy: 0.7043
# Epoch 39/50
# 238/238 [==============================] - 47s 198ms/step - loss: 0.7280 - accuracy: 0.7748 - val_loss: 1.1922 - val_accuracy: 0.7085
# Epoch 40/50
# 238/238 [==============================] - 48s 201ms/step - loss: 0.7299 - accuracy: 0.7776 - val_loss: 1.2054 - val_accuracy: 0.6936
# Epoch 41/50
# 238/238 [==============================] - 47s 198ms/step - loss: 0.6954 - accuracy: 0.7885 - val_loss: 1.2186 - val_accuracy: 0.6787
# Epoch 42/50
# 238/238 [==============================] - 47s 198ms/step - loss: 0.7042 - accuracy: 0.7876 - val_loss: 1.2265 - val_accuracy: 0.6957
# Epoch 43/50
# 238/238 [==============================] - 47s 197ms/step - loss: 0.6964 - accuracy: 0.7922 - val_loss: 1.2075 - val_accuracy: 0.7191
# Epoch 44/50
# 238/238 [==============================] - 47s 198ms/step - loss: 0.6751 - accuracy: 0.7889 - val_loss: 1.1579 - val_accuracy: 0.7085
# Epoch 45/50
# 238/238 [==============================] - 47s 198ms/step - loss: 0.6534 - accuracy: 0.7952 - val_loss: 1.1420 - val_accuracy: 0.7085
# Epoch 46/50
# 238/238 [==============================] - 47s 199ms/step - loss: 0.6487 - accuracy: 0.8001 - val_loss: 1.2565 - val_accuracy: 0.7106
# Epoch 47/50
# 238/238 [==============================] - 47s 198ms/step - loss: 0.6307 - accuracy: 0.8079 - val_loss: 1.2294 - val_accuracy: 0.7064
# Epoch 48/50
# 238/238 [==============================] - 47s 196ms/step - loss: 0.6359 - accuracy: 0.8036 - val_loss: 1.2170 - val_accuracy: 0.7106
# Epoch 49/50
# 238/238 [==============================] - 47s 199ms/step - loss: 0.6281 - accuracy: 0.8028 - val_loss: 1.1977 - val_accuracy: 0.7255
# Epoch 50/50
# 238/238 [==============================] - 47s 199ms/step - loss: 0.6173 - accuracy: 0.8048 - val_loss: 1.2586 - val_accuracy: 0.7021

# %%
#Plot the graph to check training and testing accuracy over the period of time
plt.figure(figsize=(13,5))
plt.title("Accuracy vs Epochs")
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.legend(loc='best')
plt.show()

# %%
y_pred = model.predict(x_test)
predicted_classes=[]
for i in range(len(y_test)):
    predicted_classes.append(np.argmax(y_pred[i]))

# %%
#Test Accuracy
accuracy_score(y_test, predicted_classes)
# Out:
# 0.7085106382978723

# %%
#Confusion Matrix
plt.figure(figsize=(25,25))
plt.title("Confusion matrix")
cm=confusion_matrix(y_test, predicted_classes)
plt.imshow(cm)
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment="center")
plt.show()

# %% [markdown]
# # Stacking

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
model_bagging = BaggingClassifier(base_estimator=model)

model_bagging.fit(x_train, y_train)
model_bagging.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_33/3753242831.py in <module>
#       3 model_bagging = BaggingClassifier(base_estimator=model)
#       4
# ----> 5 model_bagging.fit(x_train, y_train)
#       6 model_bagging.score(x_test, y_test)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_bagging.py in fit(self, X, y, sample_weight)
#     265             dtype=None,
#     266             force_all_finite=False,
# --> 267             multi_output=True,
#     268         )
#     269         return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     974         ensure_min_samples=ensure_min_samples,
#     975         ensure_min_features=ensure_min_features,
# --> 976         estimator=estimator,
#     977     )
#     978
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     794             raise ValueError(
#     795                 "Found array with dim %d. %s expected <= 2."
# --> 796                 % (array.ndim, estimator_name)
#     797             )
#     798
#
# ValueError: Found array with dim 5. Estimator expected <= 2.

# %% [markdown]
# # Model 2

# %%
model = Sequential()

model.add(LSTM(filters = 16, kernel_size=(3,3), activation='LeakyReLU', data_format='channels_last', return_sequences=True, recurrent_dropout=0.2, input_shape=(x_train.shape[1],x_train.shape[2], x_train.shape[3], 3)))
model.add(MaxPooling3D(pool_size=(1,2,2), padding='same', data_format='channels_last'))
model.add(TimeDistributed(Dropout(0.2)))

model.add(LSTM(filters = 16, kernel_size=(3,3), activation='LeakyReLU', data_format='channels_last', return_sequences=True, recurrent_dropout=0.2))
model.add(MaxPooling3D(pool_size=(1,2,2), padding='same', data_format='channels_last'))
model.add(TimeDistributed(Dropout(0.2)))

model.add(LSTM(filters = 16, kernel_size=(3,3), activation='LeakyReLU', data_format='channels_last', return_sequences=True, recurrent_dropout=0.2))
model.add(MaxPooling3D(pool_size=(1,2,2), padding='same', data_format='channels_last'))
model.add(TimeDistributed(Dropout(0.2)))

model.add(LSTM(filters = 16, kernel_size=(3,3), activation='LeakyReLU', data_format='channels_last', return_sequences=True, recurrent_dropout=0.2))
model.add(MaxPooling3D(pool_size=(1,2,2), padding='same', data_format='channels_last'))
model.add(TimeDistributed(Dropout(0.2)))

model.add(Flatten())
          
model.add(Dense(60, activation='softmax'))
model.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_33/1897130832.py in <module>
#       1 model = Sequential()
#       2
# ----> 3 model.add(LSTM(filters = 16, kernel_size=(3,3), activation='LeakyReLU', data_format='channels_last', return_sequences=True, recurrent_dropout=0.2, input_shape=(x_train.shape[1],x_train.shape[2], x_train.shape[3], 3)))
#       4 model.add(MaxPooling3D(pool_size=(1,2,2), padding='same', data_format='channels_last'))
#       5 model.add(TimeDistributed(Dropout(0.2)))
#
# TypeError: __init__() missing 1 required positional argument: 'units'

# %% [markdown]
# # Save the Model

# %%
model.save('CNN_Model.h5')
